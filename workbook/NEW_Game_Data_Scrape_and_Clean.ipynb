# %% [markdown]
# # Game Data Scraper & Cleaner
# - created 12/9/24
# - refactor of legacy code from Game_Data_Scraper_1 and Game_Data_Cleaner

# %%
## Dependencies
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import time
import logging
from tqdm import tqdm
import re
import os 
from sqlalchemy import create_engine
import sqlite3


# Create timestamp string to use in file names
timestamp = time.strftime("%Y%m%d-%H%M%S")

## FILE PATHS and CONSTANTS
#Local Folder paths
temp_folder = os.path.join('..', 'TEMP')
data_folder = os.path.join('..', 'data')
db_folder = os.path.join(data_folder, 'db')
log_folder = os.path.join(temp_folder, 'logs')

# Check Paths
if not os.path.exists(temp_folder):
    os.makedirs(temp_folder)
if not os.path.exists(data_folder):
    os.makedirs(data_folder)
if not os.path.exists(db_folder):
    os.makedirs(db_folder)

# Remote URL
base_url = 'https://www.collegehockeynews.com' ## Base usl for box scores and metrics
current_year_url = 'https://www.collegehockeynews.com/schedules/?season=20242025' ## Current year schedule


## Logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)
logger.info('Logging Started')

# Database Name
# DB_FILE_NAME = 'CHN_2024_YTD_Stats.db'
# DB_FILE_NAME = '2024_Dec_03_CLEAN.db'
# DB_FILE_NAME = 'Test_Empty.db'
DB_FILE_NAME = '12_10_Test_p2.db'
# Out:
# 2024-12-10 23:52:50,771 - INFO - Logging Started

# %% [markdown]
# ### Initiate DB Connection
# - backup and open DB file if it exists
# - create new DB file with DB_FILE_NAME if none exists

# %%
## Database Path
db_path = os.path.join(db_folder, DB_FILE_NAME)
# Create Backup in TEMP folder with datetime stamp
backup_db_path = os.path.join(temp_folder, f"{DB_FILE_NAME}_{timestamp}.backup")
# backup_db_path = os.path.join(temp_folder, f"{DB_FILE_NAME}.backup")

# Check if the database file exists
if os.path.exists(db_path):
    # Backup the existing database
    logger.info(f"Database file found at {db_path}. Backing it up to {backup_db_path}.")
    try:
        # Perform the backup
        with open(db_path, 'rb') as original_db, open(backup_db_path, 'wb') as backup_db:
            backup_db.write(original_db.read())
        logger.info(f"Backup successful: {backup_db_path}")
    except Exception as e:
        logger.error(f"Failed to back up the database: {e}")
else:
    logger.info(f"No database file found at {db_path}. A new database will be created.")

# Create a database connection
try:
    engine = create_engine(f"sqlite:///{db_path}")
    conn = sqlite3.connect(db_path)
    logger.info(f"Database connection established at {db_path}")
except Exception as e:
    logger.error(f"Failed to establish database connection: {e}")
    raise
# Out:
# 2024-12-10 23:52:50,787 - INFO - No database file found at ..\data\db\12_10_Test_p2.db. A new database will be created.
# 2024-12-10 23:52:50,804 - INFO - Database connection established at ..\data\db\12_10_Test_p2.db

# %% [markdown]
# #### Create a Dictionary of Team names and abbreviations
# - from arena_school_info table

# %%
## Load school infomation from arena_school_info.csv
school_info_df = pd.read_csv(os.path.join(data_folder, 'arena_school_info.csv'))

# Create a dictionary for abbreviations to full team names
abbreviation_to_fullname = school_info_df.set_index('abv')['School'].to_dict()

# Define a function to replace abbreviations in a column with full team names
def replace_abbreviations_with_fullnames(df, column_name, abbreviation_dict):
    """
    Replaces abbreviations in the specified column of a DataFrame with full team names.
    
    Args:
        df (pd.DataFrame): The DataFrame containing the column to process.
        column_name (str): The column name where abbreviations need to be replaced.
        abbreviation_dict (dict): Dictionary mapping abbreviations to full names.
    
    Returns:
        pd.DataFrame: DataFrame with updated column values.
    """
    df[column_name] = df[column_name].replace(abbreviation_dict)
    return df

# %% [markdown]
# ### Download a table of every game in CHN database for the selected season
# - output games_df table of every game listed on CHN site
# - Clean team names of unwanted characters and create unique Game_ID

# %%
## Function to Parse the Current Season Schedule / Results Page
def parse_current_season(url):
    """
    Parses the current season schedule/results page.
    Args:
        url (str): URL of the current season schedule/results page.

    Returns:
        list: Parsed data as a list of rows.
    """
    import requests
    from bs4 import BeautifulSoup

    # Initialize variables
    current_date, current_conference, game_notes = None, None, None
    data = []  # List to store game data

    # Fetch the page
    response = requests.get(url)
    if response.status_code != 200:
        raise ValueError(f"Failed to retrieve data from {url}, status code {response.status_code}")

    # Parse the page with BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    rows = soup.find_all('tr')

    # Process each row
    for row in rows:
        row_class = row.get('class')
        
        if row_class == ['stats-section']:  # Date row
            current_date = row.find('td').text.strip()
        elif row_class == ['sked-header']:  # Conference row
            current_conference = row.find('td').text.strip()
        elif len(row.find_all('td')) == 2:  # Game notes row
            game_notes = row.find_all('td')[1].text.strip()
        elif row.get('valign') == 'top':  # Game data row
            game_data = extract_game_data(row, current_date, current_conference, game_notes)
            if game_data:
                data.append(game_data)
            game_notes = None  # Reset game notes for the next row

    return data


def extract_game_data(row, current_date, current_conference, game_notes):
    """
    Extracts game data from a table row.
    Args:
        row (Tag): BeautifulSoup row tag.
        current_date (str): Current date of the game.
        current_conference (str): Current conference of the game.
        game_notes (str): Notes for the game.

    Returns:
        list: Extracted game data or None if row is invalid.
    """
    cells = row.find_all('td')
    if len(cells) < 9:
        return None

    # Extract data
    home_team = clean_team_name(cells[3].text.strip())
    home_team_link = cells[3].find('a')['href'] if cells[3].find('a') else None
    home_score = cells[4].text.strip()

    # home_team = clean_team_name(cells[0].text.strip())
    # home_team_link = cells[0].find('a')['href'] if cells[0].find('a') else None
    # home_score = cells[1].text.strip()

    away_team = clean_team_name(cells[0].text.strip())
    away_team_link = cells[0].find('a')['href'] if cells[0].find('a') else None
    away_score = cells[1].text.strip()

    ot = cells[5].text.strip()
    box_link = cells[7].find('a')['href'] if cells[7].find('a') else None
    metrics_link = cells[8].find('a')['href'] if cells[8].find('a') else None

    # Optional game notes
    game_notes_cell = cells[-1].find('small')
    game_notes = game_notes_cell.text.strip() if game_notes_cell else game_notes

    return [
        current_date, current_conference, game_notes,
        away_team, away_team_link, away_score,
        home_team, home_team_link, home_score,
        
        ot, box_link, metrics_link
    ]


def clean_team_name(team_name):
    """
    Cleans the team name by removing unwanted characters.
    Args:
        team_name (str): Team name.

    Returns:
        str: Cleaned team name.
    """
    # Replace unwanted characters with an empty string
    return team_name.replace('-', ' ').replace('.', '').replace("'", '').strip()


## Call the function
parsed_data = parse_current_season(current_year_url)

## Create a DataFrame from the parsed data
columns = [
    'Date', 'Conference', 'Game_Notes', 'Away_Team', 'Away_Team_Link', 'Away_Score',
    'Home_Team', 'Home_Team_Link', 'Home_Score',  'OT',
    'Box_Link', 'Metrics_Link'
]
df = pd.DataFrame(parsed_data, columns=columns)

## Process the DataFrame
# Extract the day of the week and reformat the date
df['Day'] = pd.to_datetime(df['Date']).dt.day_name()
df['Date'] = pd.to_datetime(df['Date']).dt.strftime('%Y-%m-%d')

# %%
def generate_game_id(row):
    """
    Generates a unique Game_ID based on the date, home team, and away team.
    Args:
        row (pd.Series): A row of the DataFrame.

    Returns:
        str: A unique Game_ID.
    """
    return f'{row.Date}-{row.Away_Team}-{row.Home_Team}'


def clean_column_data(df):
    """
    Cleans team names and ensures consistent formatting for the DataFrame columns.
    Args:
        df (pd.DataFrame): The DataFrame to clean.

    Returns:
        pd.DataFrame: The cleaned DataFrame.
    """
    # Remove hyphens from team names
    df['Home_Team'] = df['Home_Team'].str.replace('-', ' ', regex=False)
    df['Away_Team'] = df['Away_Team'].str.replace('-', ' ', regex=False)

    # Filter out games that haven't been played yet
    df = df[df['Home_Score'] != '']

    # Replace NaN values in Metrics_Link with an empty string
    df['Metrics_Link'] = df['Metrics_Link'].fillna('')

    return df


# Apply the cleaning function to the DataFrame
df = clean_column_data(df)

# Generate Game_ID column
df['Game_ID'] = df.apply(generate_game_id, axis=1)
# Out:
# C:\Users\jbanc\AppData\Local\Temp\ipykernel_7824\579037569.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Metrics_Link'] = df['Metrics_Link'].fillna('')

# %% [markdown]
# #### Compare game results table to games already in the DB

# %%
def filter_and_compare_games(df, conn, recent_days=5):
    """
    Compares the Game_ID in the extracted dataframe to the database, filters exhibition games,
    and prints a summary of game counts. Handles cases where the database is empty or does not exist.

    Args:
        df (pd.DataFrame): Extracted games dataframe.
        conn (sqlite3.Connection): Database connection.
        recent_days (int): Number of recent days to re-scrape games for updates.

    Returns:
        pd.DataFrame: DataFrame of games to scrape.
    """
    import datetime

    # Print initial game count
    total_games = len(df)
    print(f"Total games in the extracted dataset: {total_games}")

    # Filter out exhibition games
    df = df[df['Conference'] != 'Exhibition']
    filtered_games = len(df)
    print(f"Games remaining after filtering exhibition games: {filtered_games}")

    # Check if the database has any data in the game_details table
    try:
        existing_game_ids_query = "SELECT DISTINCT Game_ID FROM game_details"
        existing_game_ids = pd.read_sql(existing_game_ids_query, conn)['Game_ID'].tolist()
    except Exception as e:
        logging.warning(f"Database access failed or no game_details table found: {e}")
        existing_game_ids = []  # Treat as no games in the database

    # Handle empty database: scrape all games
    if not existing_game_ids:
        print("Database is empty or non-existent. Scraping all available games.")
        return df

    # Find games not in the database
    df['In_Database'] = df['Game_ID'].isin(existing_game_ids)
    new_games_df = df[~df['In_Database']]
    games_not_in_dataset = len(new_games_df)
    print(f"Games not in the database: {games_not_in_dataset}")

    # Add recent games to the scrape list (past `recent_days`)
    recent_date_threshold = (datetime.datetime.now() - datetime.timedelta(days=recent_days)).strftime('%Y-%m-%d')
    recent_games_df = df[df['Date'] >= recent_date_threshold]
    games_to_rescrape = len(recent_games_df)
    print(f"Games to re-scrape from the last {recent_days} days: {games_to_rescrape}")

    # Combine new games and recent games for scraping
    games_to_scrape_df = pd.concat([new_games_df, recent_games_df]).drop_duplicates(subset='Game_ID')
    print(f"Total games to scrape: {len(games_to_scrape_df)}")

    return games_to_scrape_df

## ORIG CODE, GETS ERROR IF GIVEN NON EXI FILEPATH
# def filter_and_compare_games(df, conn, recent_days=5):
#     """
#     Compares the Game_ID in the extracted dataframe to the database, filters exhibition games,
#     and prints a summary of game counts.
    
#     Args:
#         df (pd.DataFrame): Extracted games dataframe.
#         conn (sqlite3.Connection): Database connection.
#         recent_days (int): Number of recent days to re-scrape games for updates.

#     Returns:
#         pd.DataFrame: DataFrame of games to scrape.
#     """
#     import datetime

#     # Print initial game count
#     total_games = len(df)
#     print(f"Total games in the extracted dataset: {total_games}")

#     # Filter out exhibition games
#     df = df[df['Conference'] != 'Exhibition']
#     filtered_games = len(df)
#     print(f"Games remaining after filtering exhibition games: {filtered_games}")

#     # Retrieve existing Game_IDs from the database
#     existing_game_ids_query = "SELECT DISTINCT Game_ID FROM game_details"  # Correct table name
#     existing_game_ids = pd.read_sql(existing_game_ids_query, conn)['Game_ID'].tolist()
#     print(f"Total games already in the database: {len(existing_game_ids)}")

#     # Find games not in the database
#     df['In_Database'] = df['Game_ID'].isin(existing_game_ids)
#     new_games_df = df[~df['In_Database']]
#     games_not_in_dataset = len(new_games_df)
#     print(f"Games not in the database: {games_not_in_dataset}")

#     # Add recent games to the scrape list (past `recent_days`)
#     recent_date_threshold = (datetime.datetime.now() - datetime.timedelta(days=recent_days)).strftime('%Y-%m-%d')
#     recent_games_df = df[df['Date'] >= recent_date_threshold]
#     games_to_rescrape = len(recent_games_df)
#     print(f"Games to re-scrape from the last {recent_days} days: {games_to_rescrape}")

#     # Combine new games and recent games for scraping
#     games_to_scrape_df = pd.concat([new_games_df, recent_games_df]).drop_duplicates(subset='Game_ID')
#     print(f"Total games to scrape: {len(games_to_scrape_df)}")

#     return games_to_scrape_df


# Example usage
games_to_scrape = filter_and_compare_games(df, conn)
# Out:
# 2024-12-10 23:52:52,761 - WARNING - Database access failed or no game_details table found: Execution failed on sql 'SELECT DISTINCT Game_ID FROM game_details': no such table: game_details
# Total games in the extracted dataset: 534
# Games remaining after filtering exhibition games: 498
# Database is empty or non-existent. Scraping all available games.

# %% [markdown]
# ## Scraping Functions
# - currently untouched from legacy code

# %% [markdown]
# <!-- ##### LEGACY CODE - WORKING FROM G_D_S_1
# -  -->

# %%
#### PARSE PLAYER STATS TABLE ####
def parse_player_summary(html_content):
    # Initialize BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')
    
    # Find the playersums div
    playersums_div = soup.find('div', id='playersums')
    if playersums_div is None:
        return "Player summaries div not found"

    # Initialize list to store player stats
    player_stats = []

    # Loop through each playersum div
    for player_sum in playersums_div.find_all('div', class_='playersum'):
        team = player_sum.find('td').text.strip()

        # Replace abbreviation and clean team name
        team = abbreviation_to_fullname.get(team, team)
        team = clean_team_name(team)
        
        # Loop through table rows
        for row in player_sum.find_all('tr'):
            cols = row.find_all('td')
            if len(cols) > 1:
                player = cols[0].text.strip()
                goals = cols[1].text.strip()
                assists = cols[2].text.strip()
                points = cols[3].text.strip()
                plus_minus = cols[4].text.strip()
                shots = cols[5].text.strip()
                pim = cols[6].text.strip()
                fowl = cols[7].text.strip() if len(cols) > 7 else None
                
                fow, fol = None, None
                win_percentage = None
                
                

                try:
                    if fowl and '‑' in fowl:  # Checking if it contains a hyphen
                        fow, fol = map(int, fowl.split('‑'))
                        total_fo = fow + fol
                        win_percentage = (fow / total_fo) * 100 if total_fo > 0 else 0
                except ValueError:
                    fow, fol, win_percentage = None, None, None

                

                
                player_stat = {
                    'Team': team,
                    'Player': player,
                    'G': goals,
                    'A': assists,
                    'Pt.': points,
                    '+/-': plus_minus,
                    'Sh': shots,
                    'PIM': pim,
                    'FOW': fow,
                    'FOL': fol,
                    'FO%': win_percentage
                }
                player_stats.append(player_stat)

    return pd.DataFrame(player_stats)


############# PARSEING SCORING SUMMARY WITH BS4
def parse_scoring_summary(html_content):
    # Initialize BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Find the scoring div and table
    scoring_div = soup.find('div', id='scoring')
    if scoring_div is None:
        logging.error("Scoring div not found")
        return None

    scoring_table = scoring_div.find('table')
    if scoring_table is None:
        logging.error("Scoring table not found within the scoring div")
        return None

    # Initialize list to store scoring events
    scoring_events = []
    period = None

    # Loop through table rows
    for row in scoring_table.find_all('tr'):
        if 'stats-section' in row.get('class', []):
            td = row.find('td')
            if td:
                period = td.text.strip()
            else:
                logging.warning("Period name not found in 'stats-section' row")
                period = "Unknown"
        else:
            cols = row.find_all('td')
            if len(cols) > 1:
                try:
                    team = cols[0].text.strip()
                    team = abbreviation_to_fullname.get(team, team)  # Replace abbreviation
                    team = clean_team_name(team)  # Clean team name
                    pp = cols[1].text.strip()

                    player_data = cols[3].text.strip()
                    match = re.match(r"(.+)\s\((\d+)\)", player_data)
                    player = match.group(1) if match else player_data
                    goals = int(match.group(2)) if match else None

                    assist_data_raw = cols[4].text.strip()
                    assist_data = assist_data_raw.split(", ") if assist_data_raw else []
                    assist1 = assist_data[0] if len(assist_data) > 0 else None
                    assist2 = assist_data[1] if len(assist_data) > 1 else None

                    time = cols[5].text.strip()

                    scoring_event = {
                        'Period': period,
                        'Team': team,
                        'PP': pp,
                        'Player': player,
                        'Player_Goals': goals,
                        'Assist1': assist1,
                        'Assist2': assist2,
                        'Time': time
                    }
                    scoring_events.append(scoring_event)
                except Exception as e:
                    logging.error(f"An error occurred while parsing a scoring event row: {e}")
            else:
                logging.warning(f"Insufficient columns in scoring row: {len(cols)}")

    return pd.DataFrame(scoring_events)


############# PARSEING PENALTY SUMMARY WITH BS4
def parse_penalty_summary(html_content):
    # Initialize BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Find the penalties div and table
    penalties_div = soup.find('div', id='penalties')
    if penalties_div is None:
        logging.error("Penalties div not found")
        return None

    penalties_table = penalties_div.find('table')
    if penalties_table is None:
        logging.error("Penalties table not found within the penalties div")
        return None

    # Initialize list to store penalty events
    penalty_events = []
    period = None

    # Loop through table rows
    for row in penalties_table.find_all('tr'):
        if 'stats-section' in row.get('class', []):
            td = row.find('td')
            if td:
                period = td.text.strip()
            else:
                logging.warning("Period name not found in 'stats-section' row")
                period = "Unknown"
        else:
            cols = row.find_all('td')
            if len(cols) > 1:
                team = cols[0].text.strip()
                team = abbreviation_to_fullname.get(team, team)  # Replace abbreviation
                team = clean_team_name(team)  # Clean team name

                player = cols[1].text.strip()
                pen_length = cols[2].text.strip()
                penalty_type = cols[3].text.strip()
                time = cols[4].text.strip()

                penalty_event = {
                    'Period': period,
                    'Team': team,
                    'Player': player,
                    'Pen_Length': pen_length,
                    'Penalty_Type': penalty_type,
                    'Time': time
                }
                penalty_events.append(penalty_event)

    return pd.DataFrame(penalty_events)


############# GOALIE SUMMARY WITH BS4
def parse_goalie_stats(html_content):
    # Initialize BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Find the goalies div and table
    goalies_div = soup.find('div', id='goalies')
    if goalies_div is None:
        logging.error("Goalies div not found")
        return None

    goalies_table = goalies_div.find('table')
    if goalies_table is None:
        logging.error("Goalies table not found within the goalies div")
        return None

    # Initialize list to store goalie stats
    goalie_stats = []
    team = None

    # Loop through table rows   
    for row in goalies_table.find_all('tr'):
        if 'stats-header' in row.get('class', []):  # Team header rows
            td = row.find('td')
            team = td.text.strip() if td else "Unknown"
            # Replace abbreviation and clean team name
            team = abbreviation_to_fullname.get(team, team)
            team = clean_team_name(team)
        else:  # Data rows
            cols = row.find_all('td')
            if len(cols) > 1:
                goalie = cols[0].text.strip()
                sv = cols[1].text.strip()
                ga = cols[2].text.strip()
                minutes = cols[3].text.strip()

                # Build goalie stat dictionary
                goalie_stat = {
                    'Team': team,
                    'Goalie': goalie,
                    'SV': sv,
                    'GA': ga,
                    'Minutes': minutes
                }
                goalie_stats.append(goalie_stat)

    # Convert list to DataFrame
    return pd.DataFrame(goalie_stats)


#### PARSE THE ADVANCED TEAM METRICS TABLES ####
### RETURNS WHOLE ADVANCED METRICS AS SINGLE TABLE
####################################
def parse_new_advanced_metrics(html_content):
    # Parse HTML content
    soup = BeautifulSoup(html_content, 'html.parser')
    
    # Find all tables with advanced metrics
    tables = soup.find_all('table', {'class': 'sortable metrics'})
    
    # List to store all parsed data
    all_data = []
    
    for table in tables:
        # Extract team name from the table header
        team_name = table.find('td').text.strip()
        team_name = abbreviation_to_fullname.get(team_name, team_name)  # Replace abbreviation
        team_name = clean_team_name(team_name)  # Clean team name
        
        # Extract headers (skipping the Player header)
        headers = [header.text for header in table.find_all('th')][1:]
        
        # Prepare final column headers
        col_names = ['Team', 'Player']
        for header in headers:
            col_names.append(header)
        
        # Extract player data
        rows = table.find_all('tr')[2:]  # skipping the two header rows
        for row in rows:
            player_data = [team_name]  # start with team name
            cells = row.find_all('td')
            player_data.append(cells[0].text.strip())  # player name
            for cell in cells[1:]:
                player_data.append(cell.text.strip())
            all_data.append(player_data)
    
    # Convert the list of data to a DataFrame
    df = pd.DataFrame(all_data, columns=col_names)
    return df

######## NEW TEST ###############  
def parse_advanced_metrics_tables(html_content):
    # Parse HTML content
    soup = BeautifulSoup(html_content, 'html.parser')
    
    # Find all tables with advanced metrics
    tables = soup.find_all('table', {'class': 'sortable metrics'})
    
    # List to store all parsed data
    all_data = []
    
    for table in tables:
        # Extract team name from the table header
        team_name = table.find('td').text.strip()
        team_name = abbreviation_to_fullname.get(team_name, team_name)  # Replace abbreviation
        team_name = clean_team_name(team_name)  # Clean team name
        
        # Extract headers (skipping the Player header)
        headers = [header.text for header in table.find_all('th')][1:]
        
        # Prepare final column headers
        col_names = ['Team', 'Player']
        for header in headers:
            col_names.append(header)
        
        # Extract player data
        rows = table.find_all('tr')[2:]  # skipping the two header rows
        for row in rows:
            player_data = [team_name]  # start with team name
            cells = row.find_all('td')
            player_data.append(cells[0].text.strip())  # player name
            for cell in cells[1:]:
                player_data.append(cell.text.strip())
            all_data.append(player_data)
    
    # Convert the list of data to a DataFrame
    df = pd.DataFrame(all_data, columns=col_names)
    return df

# Parsing the line chart information with specific positions for forwards and defensemen.
def parse_line_chart(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    line_chart_div = soup.find('div', id='linechart')

    if line_chart_div is None:
        logging.error("Line chart div not found")
        return pd.DataFrame()

    line_data = []

    for team_div in line_chart_div.find_all('div', recursive=False):
        h3 = team_div.find('h3')
        if h3 is None:
            logging.warning("Team name not found")
            continue
        
        team_name = h3.text.strip()
        # Replace abbreviation and clean team name
        team_name = abbreviation_to_fullname.get(team_name, team_name)
        team_name = clean_team_name(team_name)
        
        for line_type_div in team_div.find_all('div', recursive=False):
            line_type = line_type_div.get('class')[0] if line_type_div.get('class') else None
            if line_type is None:
                logging.warning("Line type not found")
                continue
            
            if line_type == 'f':
                position_types = ['Left Wing', 'Center', 'Right Wing']
            elif line_type == 'd':
                position_types = ['Left D', 'Right D']
            elif line_type == 'x':
                position_types = ['Extra']
            elif line_type == 'g':
                position_types = ['Goalie']
                goalie_count = 1  # Initialize goalie count
            else:
                continue

            players = line_type_div.find_all('div')
            if not players:
                logging.warning(f"No players found for {team_name} in {line_type}")
                continue
            
            for i, player in enumerate(players):
                player_name = player.text.strip()
                if line_type == 'x':
                    player_name = player_name.split(' ')[0]
                if line_type == 'g':
                    line_number = f"Goalie {goalie_count}"
                    goalie_count += 1
                else:
                    line_number = i // len(position_types) + 1

                position = position_types[i % len(position_types)]
                line_data.append({
                    'Team': team_name,
                    'Line': line_number,
                    'Position': position,
                    'Player': player_name
                })

    if not line_data:
        logging.error("No line data was collected")

    df = pd.DataFrame(line_data)
    
    # # Log DataFrame info for debugging
    # if df.empty:
    #     logging.warning("Generated line chart DataFrame is empty.")
    # else:
    #     logging.info(f"Generated line chart DataFrame with columns: {df.columns.tolist()}")

    return df

from sqlalchemy import inspect, text

def ensure_columns_exist(table_name, columns, engine):
    """
    Ensures that the specified columns exist in the given table. Adds them if they are missing.
    
    Args:
        table_name (str): Name of the table.
        columns (list): List of column names to check/add.
        engine (sqlalchemy.engine): SQLAlchemy database engine.
    """
    inspector = inspect(engine)
    existing_columns = [col['name'] for col in inspector.get_columns(table_name)]

    missing_columns = [col for col in columns if col not in existing_columns]

    if missing_columns:
        with engine.connect() as conn:
            for col in missing_columns:
                sql = text(f"ALTER TABLE {table_name} ADD COLUMN {col} INTEGER DEFAULT 0;")
                conn.execute(sql)
                logging.info(f"Added missing column: {col} to table: {table_name}")

### Get the Linescore Elements - Score, shots, ect by period####
### NEEDS UPDATE NOW THAT POSTSEASON MEAND 5th, 6th, ect PERIODS
def parse_linescore(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    linescore_data = []
    
    # Parsing the Goals table
    goals_table = soup.select_one("#goals table")
    if goals_table is None:
        logging.error("Goals table not found")
        return None
    
    rows = goals_table.select('tbody tr')
    if not rows:
        logging.warning("No rows found in Goals table")
        return None
    
    for row in rows:
        team_data = {}
        td = row.select_one('td')
        if td:
            team_data['Team'] = td.text
        else:
            logging.warning("Team name not found in Goals table")
            continue

        goals = row.select('td')[1:]
        for i, goal in enumerate(goals):
            period = i + 1
            column_name = f'goals{period}' if i < len(goals) - 1 else 'goalsT'
            team_data[column_name] = int(goal.text)
        
        linescore_data.append(team_data)
    

    # Parsing the Shots table
    shots_table = soup.select_one("#shots table")
    if shots_table is None:
        logging.error("Shots table not found")
        return None

    rows = shots_table.select('tbody tr')
    if not rows:
        logging.warning("No rows found in Shots table")
        return None

    for i, row in enumerate(rows):
        shots = row.select('td')[1:]
        if not shots:
            logging.warning(f"No shot data found for row {i+1} in Shots table")
            continue

        for j, shot in enumerate(shots):
            period = j + 1
            column_name = f'shots{period}' if j < len(shots) - 1 else 'shotsT'
            try:
                linescore_data[i][column_name] = int(shot.text.strip())
            except ValueError:
                logging.warning(f"Could not convert shot data to integer for row {i+1}, column {j+1}")
                linescore_data[i][column_name] = None

    # Parsing the PP table
    pp_table = soup.select_one("#pp table")
    if pp_table is None:
        logging.error("PP table not found")
        return None

    rows = pp_table.select('tbody tr')
    if not rows:
        logging.warning("No rows found in PP table")
        return None

    for i, row in enumerate(rows):
        try:
            pen_pim = row.select('td')[1].text.split('‑')
            linescore_data[i]['Pen'] = int(pen_pim[0])
            linescore_data[i]['PIM'] = int(pen_pim[1])

            ppg_ppo = row.select('td')[2].text.split('‑')
            linescore_data[i]['PPG'] = int(ppg_ppo[0])
            linescore_data[i]['PPO'] = int(ppg_ppo[1])

            fow_fol = row.select('td')[3].text.split('‑')
            linescore_data[i]['FOW'] = int(fow_fol[0])
            linescore_data[i]['FOL'] = int(fow_fol[1])
            linescore_data[i]['FOW%'] = (linescore_data[i]['FOW'] / (linescore_data[i]['FOW'] + linescore_data[i]['FOL'])) * 100

        except (ValueError, IndexError) as e:
            logging.warning(f"Could not process PP data for row {i+1}. Error: {e}")
            continue

    # Convert to DataFrame early
    df = pd.DataFrame(linescore_data)

    # Ensure all columns exist
    expected_goals_columns = [f'goals{i}' for i in range(1, 7)] + ['goalsT']
    expected_shots_columns = [f'shots{i}' for i in range(1, 7)] + ['shotsT']

    for col in expected_goals_columns + expected_shots_columns:
        if col not in df.columns:
            df[col] = 0

    # Return the final DataFrame
    return df



# Function to parse game details table
def parse_game_details(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    meta_div = soup.find('div', {'id': 'meta'})
    if meta_div is None:
        logging.error("Meta div not found")
        return None
    
    game_details_div = meta_div.find_all('div')[-1]
    if game_details_div is None:
        logging.error("Game details div not found")
        return None
    
    try:
        date_str = game_details_div.h4.string
        day_of_week, date = date_str.split(", ", 1)
        
        p_elements = game_details_div.find_all('p')
        
        # Extract conference and location details
        for p in p_elements:
            if "Game" in p.text:  # e.g., "Big Ten Game"
                details_strs = p.get_text(separator='|').split('|')
                conference = details_strs[0]
                location = details_strs[-1].split('at ')[-1]
                break
        else:  # Defaults if not found
            conference, location = None, None
        
        # Extract referees and assistant referees details
        for p in p_elements:
            if "Referees" in p.text:
                refs_str = p.strong.next_sibling if p.strong else None
                asst_refs_str = p.find_all('strong')[1].next_sibling if len(p.find_all('strong')) > 1 else None
                break
        else:  # Defaults if not found
            refs_str, asst_refs_str = None, None
        
        refs = refs_str.split(', ') if refs_str else []
        asst_refs = asst_refs_str.split(', ') if asst_refs_str else []
        refs = [re.sub(r'[^a-zA-Z ]+', '', ref).strip() for ref in refs]
        asst_refs = [re.sub(r'[^a-zA-Z ]+', '', ref).strip() for ref in asst_refs]
        
        # Extract attendance details using regex for better accuracy
        attendance_pattern = r"Attendance:\s?(\d+[\d,]*)"
        attendance_match = re.search(attendance_pattern, html_content)
        attendance = int(attendance_match.group(1).replace(',', '')) if attendance_match else None
        
        # Extract game details (like shootout results)
        details = None
        for p in p_elements:
            if "shootout" in p.text:
                details = p.text
                break
        
        # Clean details if present
        if details and '\n' in details:
            details = details.replace('\n', '').strip()
        if details and '\t' in details:
            details = re.sub('\t', ' ', details)
        
        game_details = {
            'Day': day_of_week,
            'Date': date,
            'Conference': conference,
            'Details': details,
            'Location': location,
            'Ref1': refs[0] if refs else None,
            'Ref2': refs[1] if len(refs) > 1 else None,
            'Asst_Ref1': asst_refs[0] if asst_refs else None,
            'Asst_Ref2': asst_refs[1] if len(asst_refs) > 1 else None,
            'Attendance': attendance
        }
        
        game_details_df = pd.DataFrame([game_details])
        return game_details_df

    except (AttributeError, IndexError, ValueError) as e:
        logging.error(f"Error while parsing game details: {e}")
        return None


# Parse the box score page - player stats table (G, A, Pt, +/-, Sh, PIM)
def parse_box_score(box_score_html):
    # Initialize DataFrames to None
    scoring_summary = penalty_summary = goalie_stats = player_stats = line_chart = linescore = game_details = None
    
    try:
        scoring_summary = parse_scoring_summary(box_score_html)
    except Exception as e:
        print(f"Error in parse_scoring_summary: {e}")
    
    try:
        penalty_summary = parse_penalty_summary(box_score_html)
    except Exception as e:
        print(f"Error in parse_penalty_summary: {e}")
    
    try:
        goalie_stats = parse_goalie_stats(box_score_html)
    except Exception as e:
        print(f"Error in parse_goalie_stats: {e}")
    
    try:
        player_stats = parse_player_summary(box_score_html)
    except Exception as e:
        print(f"Error in parse_player_summary: {e}")
    
    try:
        line_chart = parse_line_chart(box_score_html)
        if line_chart.empty:
            logging.info("Line chart is empty. Skipping the insert for this game.")
        else:
            logging.info(f"Line chart DataFrame structure: {line_chart.dtypes}")

        # Insert into database (make sure this part works as expected)

    except Exception as e:
        logging.error(f"Error in parse_line_chart: {e}")


    try:
        linescore = parse_linescore(box_score_html)

        if not linescore.empty:
            parse_linescore(box_score_html)
        else:
            logging.warning("No linescore data to save for this game.")
    except Exception as e:
        logging.error(f"Error processing linescore: {e}")
    
    # try:
    #     linescore = parse_linescore(box_score_html)
    # except Exception as e:
    #     print(f"Error in parse_linescore: {e}")
    
    try:
        game_details = parse_game_details(box_score_html)
    except Exception as e:
        print(f"Error in parse_game_details: {e}")
    
    # Combine DataFrames into a list
    all_dfs = [game_details, scoring_summary, penalty_summary, goalie_stats, player_stats, line_chart, linescore]
    
    return all_dfs

def rename_duplicate_columns(df):
    """
    Renames duplicate columns in a DataFrame to make them unique.
    Args:
        df (pd.DataFrame): The DataFrame to process.

    Returns:
        pd.DataFrame: DataFrame with unique column names.
    """
    cols = pd.Series(df.columns)
    for dup in df.columns[df.columns.duplicated()].unique(): 
        cols[df.columns.get_loc(dup)] = [f"{dup}_{i}" if i != 0 else dup for i in range(sum(df.columns == dup))]
    df.columns = cols
    return df

# %% [markdown]
# ##### End Legacy Code

# %%
from tqdm import tqdm
import logging
import requests
import pandas as pd
import time
from sqlalchemy import create_engine
from sqlalchemy import inspect, text

def ensure_columns_exist(table_name, columns, engine):
    """
    Ensures that the specified columns exist in the given table. Adds them if missing.

    Args:
        table_name (str): Name of the table.
        columns (list): List of column names to check/add.
        engine (sqlalchemy.engine): SQLAlchemy database engine.
    """
    inspector = inspect(engine)
    existing_columns = [col['name'] for col in inspector.get_columns(table_name)]

    missing_columns = [col for col in columns if col not in existing_columns]

    if missing_columns:
        with engine.connect() as conn:
            for col in missing_columns:
                sql = text(f"ALTER TABLE {table_name} ADD COLUMN {col} INTEGER DEFAULT 0;")
                conn.execute(sql)
                logging.info(f"Added missing column: {col} to table: {table_name}")

def process_and_save_linescore(linescore_df, engine, table_name="linescore"):
    """
    Process and save the linescore DataFrame to the database, ensuring schema alignment.

    Args:
        linescore_df (pd.DataFrame): Linescore DataFrame.
        engine (sqlalchemy.engine): Database engine.
        table_name (str): Table name in the database.
    """
    # Dynamically ensure all columns exist in the database table
    ensure_columns_exist(table_name, linescore_df.columns, engine)

    # Save the DataFrame to the database
    linescore_df.to_sql(table_name, engine, if_exists='append', index=False)
    logging.info(f"Linescore data saved to table: {table_name}")




def fetch_and_save_data(row, base_url, game_id, conn):
    """
    Fetches and parses data for a single game, then saves it to the database.
    Args:
        row (pd.Series): Row from the games DataFrame containing game details.
        base_url (str): Base URL for the scraping website.
        game_id (str): Unique game identifier.
        conn (sqlite3.Connection): SQLite connection to the database.

    Returns:
        bool: True if successful, False otherwise.
    """
    try:
        box_score_url = f"{base_url}{row['Box_Link']}"
        metrics_url = f"{base_url}{row['Metrics_Link']}" if row['Metrics_Link'] else None

        # Fetch HTML for box score
        box_score_response = requests.get(box_score_url, timeout=10)
        box_score_response.raise_for_status()
        box_score_html = box_score_response.text

        # Parse box score data
        box_score_dfs = parse_box_score(box_score_html)

        # Fetch and parse advanced metrics if available
        if metrics_url:
            metrics_response = requests.get(metrics_url, timeout=10)
            metrics_response.raise_for_status()
            metrics_html = metrics_response.text
            advanced_metrics_df = parse_advanced_metrics_tables(metrics_html)
        else:
            advanced_metrics_df = pd.DataFrame()

        # Combine all DataFrames
        all_dfs = box_score_dfs + [advanced_metrics_df]

        # Apply Game_ID and remove duplicate columns
        for df in all_dfs:
            if df is not None and not df.empty:
                df['Game_ID'] = game_id
                df = rename_duplicate_columns(df)

        # Save data to database
        table_names = [
            'game_details', 'scoring_summary', 'penalty_summary',
            'goalie_stats', 'player_stats', 'line_chart', 'linescore', 'advanced_metrics'
        ]

        for df, table in zip(all_dfs, table_names):
            if df is not None and not df.empty:
                df.to_sql(table, conn, if_exists='append', index=False)

        logging.info(f"Successfully scraped and stored data for game: {game_id}")
        return True

    except requests.exceptions.RequestException as e:
        logging.error(f"Network error for game {game_id}: {e}")
    except Exception as e:
        logging.error(f"Error processing game {game_id}: {e}")

    return False


def scrape_games_and_store(sampled_games, base_url, conn):
    """
    Main function to scrape and store data for a list of games.
    Args:
        sampled_games (pd.DataFrame): DataFrame of games to scrape.
        base_url (str): Base URL for the scraping website.
        conn (sqlite3.Connection): SQLite connection to the database.

    Returns:
        None
    """
    error_count = 0
    error_games = []

    for _, row in tqdm(sampled_games.iterrows(), total=sampled_games.shape[0], desc="Scraping games"):
        game_id = f"{row['Date']}-{row['Home_Team']}-{row['Away_Team']}"
        retries = 3
        success = False

        while retries > 0 and not success:
            success = fetch_and_save_data(row, base_url, game_id, conn)
            if not success:
                retries -= 1
                time.sleep(5)  # Wait before retrying

        if not success:
            error_count += 1
            error_games.append(game_id)

    logging.info(f"Scraping completed with {error_count} errors.")
    if error_games:
        logging.warning(f"Failed games: {error_games}")

# %% [markdown]
# ## Call Functions to Perform scrape

# %%
## Call the function to scrape and store data from the games
# Example: Scraping games and storing results

# Example Usage
if __name__ == "__main__":
    # Set up database connection
    db_path = "../TEMP/CHN_Scrape_TEST_6.db"
    conn = sqlite3.connect(db_path)

    # Set up logging
    logging.basicConfig(level=logging.INFO, format="%(asctime)s [%(levelname)s] %(message)s")

    
    # Base URL
    base_url = "https://www.collegehockeynews.com"

    # Scrape and store games
    scrape_games_and_store(games_to_scrape, base_url, conn)

    # Close database connection
    # conn.close()
# Out:
# Scraping games:   0%|          | 0/498 [00:00<?, ?it/s]2024-12-10 23:52:53,804 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:52:54,556 - INFO - Successfully scraped and stored data for game: 2024-10-04-Lake Superior-Michigan State
# Scraping games:   0%|          | 1/498 [00:01<14:09,  1.71s/it]2024-12-10 23:52:55,519 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:52:56,237 - INFO - Successfully scraped and stored data for game: 2024-10-04-Michigan-Minnesota State
# Scraping games:   0%|          | 2/498 [00:03<13:54,  1.68s/it]2024-12-10 23:52:57,159 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:52:57,912 - INFO - Successfully scraped and stored data for game: 2024-10-04-Air Force-Arizona State
# Scraping games:   1%|          | 3/498 [00:05<13:51,  1.68s/it]2024-12-10 23:52:58,858 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:52:59,623 - INFO - Successfully scraped and stored data for game: 2024-10-04-Mercyhurst-Bowling Green
# Scraping games:   1%|          | 4/498 [00:06<13:58,  1.70s/it]2024-12-10 23:53:00,432 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:01,276 - INFO - Successfully scraped and stored data for game: 2024-10-04-Connecticut-Colgate
# Scraping games:   1%|          | 5/498 [00:08<13:46,  1.68s/it]2024-12-10 23:53:02,138 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:02,951 - INFO - Successfully scraped and stored data for game: 2024-10-04-Ferris State-Miami
# Scraping games:   1%|          | 6/498 [00:10<13:44,  1.68s/it]2024-12-10 23:53:03,789 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:04,544 - INFO - Successfully scraped and stored data for game: 2024-10-05-Lake Superior-Michigan State
# Scraping games:   1%|▏         | 7/498 [00:11<13:29,  1.65s/it]2024-12-10 23:53:05,471 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:06,234 - INFO - Successfully scraped and stored data for game: 2024-10-05-Minnesota Duluth-Bemidji State
# Scraping games:   2%|▏         | 8/498 [00:13<13:34,  1.66s/it]2024-12-10 23:53:07,169 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:07,891 - INFO - Successfully scraped and stored data for game: 2024-10-05-Alaska Anchorage-Denver
# Scraping games:   2%|▏         | 9/498 [00:15<13:31,  1.66s/it]2024-12-10 23:53:08,848 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:09,632 - INFO - Successfully scraped and stored data for game: 2024-10-05-Michigan-Minnesota State
# Scraping games:   2%|▏         | 10/498 [00:16<13:44,  1.69s/it]2024-12-10 23:53:10,537 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:11,338 - INFO - Successfully scraped and stored data for game: 2024-10-05-Boston University-Holy Cross
# Scraping games:   2%|▏         | 11/498 [00:18<13:43,  1.69s/it]2024-12-10 23:53:12,120 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:12,917 - INFO - Successfully scraped and stored data for game: 2024-10-05-Clarkson-Canisius
# Scraping games:   2%|▏         | 12/498 [00:20<13:25,  1.66s/it]2024-12-10 23:53:13,819 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:14,587 - INFO - Successfully scraped and stored data for game: 2024-10-05-Maine-American Intl
# Scraping games:   3%|▎         | 13/498 [00:21<13:25,  1.66s/it]2024-12-10 23:53:15,548 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:16,251 - INFO - Successfully scraped and stored data for game: 2024-10-05-St Lawrence-RIT
# Scraping games:   3%|▎         | 14/498 [00:23<13:24,  1.66s/it]2024-12-10 23:53:17,170 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:17,904 - INFO - Successfully scraped and stored data for game: 2024-10-05-Bentley-Massachusetts
# Scraping games:   3%|▎         | 15/498 [00:25<13:21,  1.66s/it]2024-12-10 23:53:18,786 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:19,586 - INFO - Successfully scraped and stored data for game: 2024-10-05-Air Force-Arizona State
# Scraping games:   3%|▎         | 16/498 [00:26<13:22,  1.67s/it]2024-12-10 23:53:20,406 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:21,236 - INFO - Successfully scraped and stored data for game: 2024-10-05-Mercyhurst-Bowling Green
# Scraping games:   3%|▎         | 17/498 [00:28<13:18,  1.66s/it]2024-12-10 23:53:22,086 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:22,956 - INFO - Successfully scraped and stored data for game: 2024-10-05-Alaska-Penn State
# Scraping games:   4%|▎         | 18/498 [00:30<13:25,  1.68s/it]2024-12-10 23:53:23,871 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:24,586 - INFO - Successfully scraped and stored data for game: 2024-10-05-Connecticut-Colgate
# Scraping games:   4%|▍         | 19/498 [00:31<13:17,  1.66s/it]2024-12-10 23:53:25,518 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:26,273 - INFO - Successfully scraped and stored data for game: 2024-10-05-Ferris State-Miami
# Scraping games:   4%|▍         | 20/498 [00:33<13:18,  1.67s/it]2024-12-10 23:53:27,236 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:28,086 - INFO - Successfully scraped and stored data for game: 2024-10-06-Clarkson-RIT
# Scraping games:   4%|▍         | 21/498 [00:35<13:37,  1.71s/it]2024-12-10 23:53:28,965 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:29,737 - INFO - Successfully scraped and stored data for game: 2024-10-06-St Lawrence-Canisius
# Scraping games:   4%|▍         | 22/498 [00:36<13:26,  1.69s/it]2024-12-10 23:53:30,588 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:31,389 - INFO - Successfully scraped and stored data for game: 2024-10-06-Union-Army
# Scraping games:   5%|▍         | 23/498 [00:38<13:18,  1.68s/it]2024-12-10 23:53:32,320 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:33,054 - INFO - Successfully scraped and stored data for game: 2024-10-06-Merrimack-Stonehill
# Scraping games:   5%|▍         | 24/498 [00:40<13:15,  1.68s/it]2024-12-10 23:53:34,022 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:34,735 - INFO - Successfully scraped and stored data for game: 2024-10-06-Alaska Anchorage-Denver
# Scraping games:   5%|▌         | 25/498 [00:41<13:13,  1.68s/it]2024-12-10 23:53:35,624 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:36,353 - INFO - Successfully scraped and stored data for game: 2024-10-06-Alaska-Penn State
# Scraping games:   5%|▌         | 26/498 [00:43<13:03,  1.66s/it]2024-12-10 23:53:37,252 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:38,019 - INFO - Successfully scraped and stored data for game: 2024-10-06-St Thomas-St Cloud State
# Scraping games:   5%|▌         | 27/498 [00:45<13:02,  1.66s/it]2024-12-10 23:53:38,869 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:39,619 - INFO - Successfully scraped and stored data for game: 2024-10-11-Arizona State-Michigan
# Scraping games:   6%|▌         | 28/498 [00:46<12:54,  1.65s/it]2024-12-10 23:53:40,481 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:41,286 - INFO - Successfully scraped and stored data for game: 2024-10-11-Michigan State-Boston College
# Scraping games:   6%|▌         | 29/498 [00:48<12:53,  1.65s/it]2024-12-10 23:53:42,236 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:42,936 - INFO - Successfully scraped and stored data for game: 2024-10-11-Canisius-Rensselaer
# Scraping games:   6%|▌         | 30/498 [00:50<12:51,  1.65s/it]2024-12-10 23:53:43,835 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:44,569 - INFO - Successfully scraped and stored data for game: 2024-10-11-Clarkson-Niagara
# Scraping games:   6%|▌         | 31/498 [00:51<12:47,  1.64s/it]2024-12-10 23:53:45,502 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:46,219 - INFO - Successfully scraped and stored data for game: 2024-10-11-Colgate-Sacred Heart
# Scraping games:   6%|▋         | 32/498 [00:53<12:47,  1.65s/it]2024-12-10 23:53:47,139 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:47,954 - INFO - Successfully scraped and stored data for game: 2024-10-11-Colorado College-Northern Michigan
# Scraping games:   7%|▋         | 33/498 [00:55<12:57,  1.67s/it]2024-12-10 23:53:48,802 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:49,621 - INFO - Successfully scraped and stored data for game: 2024-10-11-Holy Cross-Connecticut
# Scraping games:   7%|▋         | 34/498 [00:56<12:57,  1.68s/it]2024-12-10 23:53:50,557 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:51,236 - INFO - Successfully scraped and stored data for game: 2024-10-11-Stonehill-Union
# Scraping games:   7%|▋         | 35/498 [00:58<12:45,  1.65s/it]2024-12-10 23:53:52,119 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:52,836 - INFO - Successfully scraped and stored data for game: 2024-10-11-Ohio State-American Intl
# Scraping games:   7%|▋         | 36/498 [00:59<12:38,  1.64s/it]2024-12-10 23:53:53,820 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:54,552 - INFO - Successfully scraped and stored data for game: 2024-10-11-St Lawrence-Notre Dame
# Scraping games:   7%|▋         | 37/498 [01:01<12:47,  1.66s/it]2024-12-10 23:53:55,487 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:56,297 - INFO - Successfully scraped and stored data for game: 2024-10-11-Western Michigan-Ferris State
# Scraping games:   8%|▊         | 38/498 [01:03<12:54,  1.68s/it]2024-12-10 23:53:57,218 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:57,979 - INFO - Successfully scraped and stored data for game: 2024-10-11-Wisconsin-Lindenwood
# Scraping games:   8%|▊         | 39/498 [01:05<12:53,  1.68s/it]2024-12-10 23:53:58,862 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:53:59,671 - INFO - Successfully scraped and stored data for game: 2024-10-11-St Thomas-Vermont
# Scraping games:   8%|▊         | 40/498 [01:06<12:53,  1.69s/it]2024-12-10 23:54:00,620 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:01,337 - INFO - Successfully scraped and stored data for game: 2024-10-11-Miami-Alaska Anchorage
# Scraping games:   8%|▊         | 41/498 [01:08<12:48,  1.68s/it]2024-12-10 23:54:02,253 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:02,985 - INFO - Successfully scraped and stored data for game: 2024-10-11-Michigan Tech-Alaska
# Scraping games:   8%|▊         | 42/498 [01:10<12:41,  1.67s/it]2024-12-10 23:54:03,956 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:04,653 - INFO - Successfully scraped and stored data for game: 2024-10-11-Minnesota State-Merrimack
# Scraping games:   9%|▊         | 43/498 [01:11<12:41,  1.67s/it]2024-12-10 23:54:05,543 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:06,366 - INFO - Successfully scraped and stored data for game: 2024-10-11-Augustana-Long Island
# Scraping games:   9%|▉         | 44/498 [01:13<12:42,  1.68s/it]2024-12-10 23:54:07,268 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:08,094 - INFO - Successfully scraped and stored data for game: 2024-10-11-Mass Lowell-Minnesota Duluth
# Scraping games:   9%|▉         | 45/498 [01:15<12:47,  1.69s/it]2024-12-10 23:54:08,901 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:09,721 - INFO - Successfully scraped and stored data for game: 2024-10-11-St Cloud State-Bemidji State
# Scraping games:   9%|▉         | 46/498 [01:16<12:36,  1.67s/it]2024-12-10 23:54:10,618 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:11,385 - INFO - Successfully scraped and stored data for game: 2024-10-11-Massachusetts-Omaha
# Scraping games:   9%|▉         | 47/498 [01:18<12:33,  1.67s/it]2024-12-10 23:54:12,363 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:13,071 - INFO - Successfully scraped and stored data for game: 2024-10-11-Air Force-Minnesota
# Scraping games:  10%|▉         | 48/498 [01:20<12:33,  1.68s/it]2024-12-10 23:54:13,965 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:14,801 - INFO - Successfully scraped and stored data for game: 2024-10-11-Mercyhurst-RIT
# Scraping games:  10%|▉         | 49/498 [01:21<12:40,  1.69s/it]2024-12-10 23:54:15,703 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:16,524 - INFO - Successfully scraped and stored data for game: 2024-10-12-Connecticut-Holy Cross
# Scraping games:  10%|█         | 50/498 [01:23<12:42,  1.70s/it]2024-12-10 23:54:17,416 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:18,195 - INFO - Successfully scraped and stored data for game: 2024-10-12-Colgate-Sacred Heart
# Scraping games:  10%|█         | 51/498 [01:25<12:36,  1.69s/it]2024-12-10 23:54:19,156 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:19,916 - INFO - Successfully scraped and stored data for game: 2024-10-12-Canisius-Rensselaer
# Scraping games:  10%|█         | 52/498 [01:27<12:40,  1.70s/it]2024-12-10 23:54:20,946 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:21,668 - INFO - Successfully scraped and stored data for game: 2024-10-12-Ohio State-American Intl
# Scraping games:  11%|█         | 53/498 [01:28<12:42,  1.71s/it]2024-12-10 23:54:22,551 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:23,368 - INFO - Successfully scraped and stored data for game: 2024-10-12-Arizona State-Michigan
# Scraping games:  11%|█         | 54/498 [01:30<12:39,  1.71s/it]2024-12-10 23:54:24,240 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:25,051 - INFO - Successfully scraped and stored data for game: 2024-10-12-Colorado College-Northern Michigan
# Scraping games:  11%|█         | 55/498 [01:32<12:33,  1.70s/it]2024-12-10 23:54:25,876 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:26,686 - INFO - Successfully scraped and stored data for game: 2024-10-12-Michigan State-Boston College
# Scraping games:  11%|█         | 56/498 [01:33<12:23,  1.68s/it]2024-12-10 23:54:27,615 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:28,351 - INFO - Successfully scraped and stored data for game: 2024-10-12-Wisconsin-Lindenwood
# Scraping games:  11%|█▏        | 57/498 [01:35<12:19,  1.68s/it]2024-12-10 23:54:29,231 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:29,948 - INFO - Successfully scraped and stored data for game: 2024-10-12-St Thomas-Vermont
# Scraping games:  12%|█▏        | 58/498 [01:37<12:07,  1.65s/it]2024-12-10 23:54:30,908 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:31,632 - INFO - Successfully scraped and stored data for game: 2024-10-12-Mass Lowell-Minnesota Duluth
# Scraping games:  12%|█▏        | 59/498 [01:38<12:09,  1.66s/it]2024-12-10 23:54:32,515 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:33,300 - INFO - Successfully scraped and stored data for game: 2024-10-12-Michigan Tech-Alaska
# Scraping games:  12%|█▏        | 60/498 [01:40<12:08,  1.66s/it]2024-12-10 23:54:34,152 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:34,973 - INFO - Successfully scraped and stored data for game: 2024-10-12-Minnesota State-Merrimack
# Scraping games:  12%|█▏        | 61/498 [01:42<12:09,  1.67s/it]2024-12-10 23:54:35,784 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:36,597 - INFO - Successfully scraped and stored data for game: 2024-10-12-North Dakota-Providence
# Scraping games:  12%|█▏        | 62/498 [01:43<12:01,  1.65s/it]2024-12-10 23:54:37,518 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:38,239 - INFO - Successfully scraped and stored data for game: 2024-10-12-Augustana-Long Island
# Scraping games:  13%|█▎        | 63/498 [01:45<11:57,  1.65s/it]2024-12-10 23:54:39,185 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:40,047 - INFO - Successfully scraped and stored data for game: 2024-10-12-Bemidji State-St Cloud State
# Scraping games:  13%|█▎        | 64/498 [01:47<12:16,  1.70s/it]2024-12-10 23:54:40,975 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:41,735 - INFO - Successfully scraped and stored data for game: 2024-10-12-Boston University-Union
# Scraping games:  13%|█▎        | 65/498 [01:48<12:13,  1.69s/it]2024-12-10 23:54:42,684 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:43,451 - INFO - Successfully scraped and stored data for game: 2024-10-12-Clarkson-Notre Dame
# Scraping games:  13%|█▎        | 66/498 [01:50<12:14,  1.70s/it]2024-12-10 23:54:44,318 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:45,158 - INFO - Successfully scraped and stored data for game: 2024-10-12-Ferris State-Western Michigan
# Scraping games:  13%|█▎        | 67/498 [01:52<12:13,  1.70s/it]2024-12-10 23:54:46,023 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:46,851 - INFO - Successfully scraped and stored data for game: 2024-10-12-New Hampshire-Bentley
# Scraping games:  14%|█▎        | 68/498 [01:54<12:12,  1.70s/it]2024-12-10 23:54:47,768 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:48,501 - INFO - Successfully scraped and stored data for game: 2024-10-12-Northeastern-Stonehill
# Scraping games:  14%|█▍        | 69/498 [01:55<12:04,  1.69s/it]2024-12-10 23:54:49,425 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:54,719 - INFO - Successfully scraped and stored data for game: 2024-10-12-Quinnipiac-Penn State
# Scraping games:  14%|█▍        | 70/498 [02:01<21:43,  3.05s/it]2024-12-10 23:54:55,726 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:56,486 - INFO - Successfully scraped and stored data for game: 2024-10-12-St Lawrence-Niagara
# Scraping games:  14%|█▍        | 71/498 [02:03<18:55,  2.66s/it]2024-12-10 23:54:57,447 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:54:59,532 - INFO - Successfully scraped and stored data for game: 2024-10-12-Miami-Alaska Anchorage
# Scraping games:  14%|█▍        | 72/498 [02:06<19:42,  2.77s/it]2024-12-10 23:55:00,380 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:01,187 - INFO - Successfully scraped and stored data for game: 2024-10-12-Mercyhurst-RIT
# Scraping games:  15%|█▍        | 73/498 [02:08<17:16,  2.44s/it]2024-12-10 23:55:01,996 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:02,780 - INFO - Successfully scraped and stored data for game: 2024-10-12-Air Force-Massachusetts
# Scraping games:  15%|█▍        | 74/498 [02:09<15:26,  2.18s/it]2024-12-10 23:55:03,724 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:04,451 - INFO - Successfully scraped and stored data for game: 2024-10-12-Omaha-Minnesota
# Scraping games:  15%|█▌        | 75/498 [02:11<14:19,  2.03s/it]2024-12-10 23:55:05,361 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:06,095 - INFO - Successfully scraped and stored data for game: 2024-10-17-Miami-Robert Morris
# Scraping games:  15%|█▌        | 76/498 [02:13<13:28,  1.91s/it]2024-12-10 23:55:06,996 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:07,718 - INFO - Successfully scraped and stored data for game: 2024-10-17-Western Michigan-Bowling Green
# Scraping games:  15%|█▌        | 77/498 [02:14<12:49,  1.83s/it]2024-12-10 23:55:08,620 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:09,400 - INFO - Successfully scraped and stored data for game: 2024-10-18-Boston University-Connecticut
# Scraping games:  16%|█▌        | 78/498 [02:16<12:29,  1.78s/it]2024-12-10 23:55:10,267 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:11,050 - INFO - Successfully scraped and stored data for game: 2024-10-18-Merrimack-New Hampshire
# Scraping games:  16%|█▌        | 79/498 [02:18<12:10,  1.74s/it]2024-12-10 23:55:11,872 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:12,671 - INFO - Successfully scraped and stored data for game: 2024-10-18-Wisconsin-Ohio State
# Scraping games:  16%|█▌        | 80/498 [02:19<11:53,  1.71s/it]2024-12-10 23:55:13,601 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:14,343 - INFO - Successfully scraped and stored data for game: 2024-10-18-Denver-Northeastern
# Scraping games:  16%|█▋        | 81/498 [02:21<11:47,  1.70s/it]2024-12-10 23:55:15,266 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:15,975 - INFO - Successfully scraped and stored data for game: 2024-10-18-Maine-Quinnipiac
# Scraping games:  16%|█▋        | 82/498 [02:23<11:38,  1.68s/it]2024-12-10 23:55:16,863 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:17,602 - INFO - Successfully scraped and stored data for game: 2024-10-18-Massachusetts-Sacred Heart
# Scraping games:  17%|█▋        | 83/498 [02:24<11:29,  1.66s/it]2024-12-10 23:55:18,550 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:19,338 - INFO - Successfully scraped and stored data for game: 2024-10-18-Michigan-St Cloud State
# Scraping games:  17%|█▋        | 84/498 [02:26<11:36,  1.68s/it]2024-12-10 23:55:20,185 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:21,020 - INFO - Successfully scraped and stored data for game: 2024-10-18-Minnesota Duluth-Minnesota
# Scraping games:  17%|█▋        | 85/498 [02:28<11:36,  1.69s/it]2024-12-10 23:55:21,882 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:22,683 - INFO - Successfully scraped and stored data for game: 2024-10-18-Providence-Arizona State
# Scraping games:  17%|█▋        | 86/498 [02:29<11:30,  1.68s/it]2024-12-10 23:55:23,561 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:24,247 - INFO - Successfully scraped and stored data for game: 2024-10-18-Rensselaer-Niagara
# Scraping games:  17%|█▋        | 87/498 [02:31<11:15,  1.64s/it]2024-12-10 23:55:25,170 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:25,895 - INFO - Successfully scraped and stored data for game: 2024-10-18-St Lawrence-Ferris State
# Scraping games:  18%|█▊        | 88/498 [02:33<11:15,  1.65s/it]2024-12-10 23:55:26,883 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:27,632 - INFO - Successfully scraped and stored data for game: 2024-10-18-Union-Mercyhurst
# Scraping games:  18%|█▊        | 89/498 [02:34<11:23,  1.67s/it]2024-12-10 23:55:28,497 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:29,390 - INFO - Successfully scraped and stored data for game: 2024-10-18-Bentley-Long Island
# Scraping games:  18%|█▊        | 90/498 [02:36<11:32,  1.70s/it]2024-12-10 23:55:30,284 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:31,044 - INFO - Successfully scraped and stored data for game: 2024-10-18-Boston College-American Intl
# Scraping games:  18%|█▊        | 91/498 [02:38<11:25,  1.68s/it]2024-12-10 23:55:31,892 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:32,734 - INFO - Successfully scraped and stored data for game: 2024-10-18-Air Force-Lindenwood
# Scraping games:  18%|█▊        | 92/498 [02:39<11:24,  1.69s/it]2024-12-10 23:55:33,598 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:34,371 - INFO - Successfully scraped and stored data for game: 2024-10-18-Notre Dame-Alaska
# Scraping games:  19%|█▊        | 93/498 [02:41<11:16,  1.67s/it]2024-12-10 23:55:35,256 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:35,957 - INFO - Successfully scraped and stored data for game: 2024-10-18-Lake Superior-Stonehill
# Scraping games:  19%|█▉        | 94/498 [02:43<11:04,  1.65s/it]2024-12-10 23:55:37,008 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:37,739 - INFO - Successfully scraped and stored data for game: 2024-10-18-Minnesota State-North Dakota
# Scraping games:  19%|█▉        | 95/498 [02:44<11:19,  1.69s/it]2024-12-10 23:55:38,614 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:39,299 - INFO - Successfully scraped and stored data for game: 2024-10-18-Omaha-Augustana
# Scraping games:  19%|█▉        | 96/498 [02:46<11:02,  1.65s/it]2024-12-10 23:55:40,233 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:41,017 - INFO - Successfully scraped and stored data for game: 2024-10-18-Northern Michigan-Alaska Anchorage
# Scraping games:  19%|█▉        | 97/498 [02:48<11:09,  1.67s/it]2024-12-10 23:55:41,902 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:42,719 - INFO - Successfully scraped and stored data for game: 2024-10-18-Mass Lowell-Colgate
# Scraping games:  20%|█▉        | 98/498 [02:49<11:11,  1.68s/it]2024-12-10 23:55:43,498 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:44,319 - INFO - Successfully scraped and stored data for game: 2024-10-19-Providence-Arizona State
# Scraping games:  20%|█▉        | 99/498 [02:51<11:02,  1.66s/it]2024-12-10 23:55:45,250 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:45,972 - INFO - Successfully scraped and stored data for game: 2024-10-19-Rensselaer-Niagara
# Scraping games:  20%|██        | 100/498 [02:53<10:59,  1.66s/it]2024-12-10 23:55:46,883 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:47,658 - INFO - Successfully scraped and stored data for game: 2024-10-19-Union-Mercyhurst
# Scraping games:  20%|██        | 101/498 [02:54<10:59,  1.66s/it]2024-12-10 23:55:48,616 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:49,417 - INFO - Successfully scraped and stored data for game: 2024-10-19-Denver-Northeastern
# Scraping games:  20%|██        | 102/498 [02:56<11:09,  1.69s/it]2024-12-10 23:55:50,266 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:51,054 - INFO - Successfully scraped and stored data for game: 2024-10-19-Minnesota Duluth-Minnesota
# Scraping games:  21%|██        | 103/498 [02:58<11:01,  1.68s/it]2024-12-10 23:55:51,900 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:52,701 - INFO - Successfully scraped and stored data for game: 2024-10-19-Mass Lowell-Colgate
# Scraping games:  21%|██        | 104/498 [02:59<10:58,  1.67s/it]2024-12-10 23:55:53,584 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:54,384 - INFO - Successfully scraped and stored data for game: 2024-10-19-Notre Dame-Alaska
# Scraping games:  21%|██        | 105/498 [03:01<10:56,  1.67s/it]2024-12-10 23:55:55,416 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:56,117 - INFO - Successfully scraped and stored data for game: 2024-10-19-Lake Superior-Stonehill
# Scraping games:  21%|██▏       | 106/498 [03:03<11:02,  1.69s/it]2024-12-10 23:55:57,000 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:57,769 - INFO - Successfully scraped and stored data for game: 2024-10-19-Minnesota State-North Dakota
# Scraping games:  21%|██▏       | 107/498 [03:04<10:56,  1.68s/it]2024-12-10 23:55:58,666 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:55:59,517 - INFO - Successfully scraped and stored data for game: 2024-10-19-Northern Michigan-Alaska Anchorage
# Scraping games:  22%|██▏       | 108/498 [03:06<11:02,  1.70s/it]2024-12-10 23:56:00,383 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:01,133 - INFO - Successfully scraped and stored data for game: 2024-10-19-Michigan-St Cloud State
# Scraping games:  22%|██▏       | 109/498 [03:08<10:51,  1.67s/it]2024-12-10 23:56:02,013 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:02,833 - INFO - Successfully scraped and stored data for game: 2024-10-19-Robert Morris-Miami
# Scraping games:  22%|██▏       | 110/498 [03:09<10:54,  1.69s/it]2024-12-10 23:56:03,772 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:04,516 - INFO - Successfully scraped and stored data for game: 2024-10-19-Sacred Heart-Massachusetts
# Scraping games:  22%|██▏       | 111/498 [03:11<10:52,  1.69s/it]2024-12-10 23:56:05,483 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:06,233 - INFO - Successfully scraped and stored data for game: 2024-10-19-St Lawrence-Ferris State
# Scraping games:  22%|██▏       | 112/498 [03:13<10:52,  1.69s/it]2024-12-10 23:56:07,166 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:07,908 - INFO - Successfully scraped and stored data for game: 2024-10-19-Bentley-Long Island
# Scraping games:  23%|██▎       | 113/498 [03:15<10:49,  1.69s/it]2024-12-10 23:56:08,816 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:09,669 - INFO - Successfully scraped and stored data for game: 2024-10-19-RIT-Bowling Green
# Scraping games:  23%|██▎       | 114/498 [03:16<10:55,  1.71s/it]2024-12-10 23:56:10,554 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:11,333 - INFO - Successfully scraped and stored data for game: 2024-10-19-Omaha-Augustana
# Scraping games:  23%|██▎       | 115/498 [03:18<10:51,  1.70s/it]2024-12-10 23:56:12,199 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:13,016 - INFO - Successfully scraped and stored data for game: 2024-10-19-Maine-Quinnipiac
# Scraping games:  23%|██▎       | 116/498 [03:20<10:45,  1.69s/it]2024-12-10 23:56:13,982 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:14,764 - INFO - Successfully scraped and stored data for game: 2024-10-19-Vermont-Clarkson
# Scraping games:  23%|██▎       | 117/498 [03:21<10:50,  1.71s/it]2024-12-10 23:56:15,632 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:16,350 - INFO - Successfully scraped and stored data for game: 2024-10-19-Wisconsin-Ohio State
# Scraping games:  24%|██▎       | 118/498 [03:23<10:35,  1.67s/it]2024-12-10 23:56:17,266 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:18,015 - INFO - Successfully scraped and stored data for game: 2024-10-19-Holy Cross-Army
# Scraping games:  24%|██▍       | 119/498 [03:25<10:32,  1.67s/it]2024-12-10 23:56:18,982 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:19,801 - INFO - Successfully scraped and stored data for game: 2024-10-20-Air Force-Lindenwood
# Scraping games:  24%|██▍       | 120/498 [03:26<10:43,  1.70s/it]2024-12-10 23:56:20,649 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:21,452 - INFO - Successfully scraped and stored data for game: 2024-10-20-Holy Cross-Army
# Scraping games:  24%|██▍       | 121/498 [03:28<10:36,  1.69s/it]2024-12-10 23:56:22,316 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:23,168 - INFO - Successfully scraped and stored data for game: 2024-10-22-Canisius-Mercyhurst
# Scraping games:  24%|██▍       | 122/498 [03:30<10:37,  1.70s/it]2024-12-10 23:56:24,182 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:24,933 - INFO - Successfully scraped and stored data for game: 2024-10-25-American Intl-Air Force
# Scraping games:  25%|██▍       | 123/498 [03:32<10:45,  1.72s/it]2024-12-10 23:56:25,882 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:26,566 - INFO - Successfully scraped and stored data for game: 2024-10-25-Robert Morris-Niagara
# Scraping games:  25%|██▍       | 124/498 [03:33<10:32,  1.69s/it]2024-12-10 23:56:27,499 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:28,216 - INFO - Successfully scraped and stored data for game: 2024-10-25-Sacred Heart-Holy Cross
# Scraping games:  25%|██▌       | 125/498 [03:35<10:25,  1.68s/it]2024-12-10 23:56:29,166 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:29,966 - INFO - Successfully scraped and stored data for game: 2024-10-25-Army-Bentley
# Scraping games:  25%|██▌       | 126/498 [03:37<10:34,  1.70s/it]2024-12-10 23:56:30,832 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:31,661 - INFO - Successfully scraped and stored data for game: 2024-10-25-Minnesota Duluth-Stonehill
# Scraping games:  26%|██▌       | 127/498 [03:38<10:30,  1.70s/it]2024-12-10 23:56:32,483 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:33,267 - INFO - Successfully scraped and stored data for game: 2024-10-25-Canisius-Michigan State
# Scraping games:  26%|██▌       | 128/498 [03:40<10:17,  1.67s/it]2024-12-10 23:56:34,216 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:34,933 - INFO - Successfully scraped and stored data for game: 2024-10-25-Denver-Wisconsin
# Scraping games:  26%|██▌       | 129/498 [03:42<10:15,  1.67s/it]2024-12-10 23:56:35,863 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:36,601 - INFO - Successfully scraped and stored data for game: 2024-10-25-Alaska Anchorage-Colorado College
# Scraping games:  26%|██▌       | 130/498 [03:43<10:13,  1.67s/it]2024-12-10 23:56:37,517 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:38,315 - INFO - Successfully scraped and stored data for game: 2024-10-25-Michigan Tech-Clarkson
# Scraping games:  26%|██▋       | 131/498 [03:45<10:19,  1.69s/it]2024-12-10 23:56:39,200 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:40,032 - INFO - Successfully scraped and stored data for game: 2024-10-25-Ohio State-Bowling Green
# Scraping games:  27%|██▋       | 132/498 [03:47<10:18,  1.69s/it]2024-12-10 23:56:40,933 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:41,782 - INFO - Successfully scraped and stored data for game: 2024-10-25-Quinnipiac-New Hampshire
# Scraping games:  27%|██▋       | 133/498 [03:48<10:24,  1.71s/it]2024-12-10 23:56:42,699 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:43,416 - INFO - Successfully scraped and stored data for game: 2024-10-25-St Cloud State-Augustana
# Scraping games:  27%|██▋       | 134/498 [03:50<10:13,  1.69s/it]2024-12-10 23:56:44,451 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:45,188 - INFO - Successfully scraped and stored data for game: 2024-10-25-Penn State-St Lawrence
# Scraping games:  27%|██▋       | 135/498 [03:52<10:21,  1.71s/it]2024-12-10 23:56:46,099 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:46,832 - INFO - Successfully scraped and stored data for game: 2024-10-25-Miami-Lindenwood
# Scraping games:  27%|██▋       | 136/498 [03:53<10:12,  1.69s/it]2024-12-10 23:56:47,765 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:48,552 - INFO - Successfully scraped and stored data for game: 2024-10-25-Notre Dame-Long Island
# Scraping games:  28%|██▊       | 137/498 [03:55<10:14,  1.70s/it]2024-12-10 23:56:49,490 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:50,299 - INFO - Successfully scraped and stored data for game: 2024-10-25-RIT-Colgate
# Scraping games:  28%|██▊       | 138/498 [03:57<10:16,  1.71s/it]2024-12-10 23:56:51,167 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:51,974 - INFO - Successfully scraped and stored data for game: 2024-10-25-Minnesota State-Omaha
# Scraping games:  28%|██▊       | 139/498 [03:59<10:12,  1.71s/it]2024-12-10 23:56:52,900 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:53,615 - INFO - Successfully scraped and stored data for game: 2024-10-25-North Dakota-Boston University
# Scraping games:  28%|██▊       | 140/498 [04:00<10:04,  1.69s/it]2024-12-10 23:56:54,573 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:55,320 - INFO - Successfully scraped and stored data for game: 2024-10-25-Northern Michigan-Arizona State
# Scraping games:  28%|██▊       | 141/498 [04:02<10:02,  1.69s/it]2024-12-10 23:56:56,265 - ERROR - Line chart div not found
# 2024-12-10 23:56:56,265 - INFO - Line chart is empty. Skipping the insert for this game.
# 2024-12-10 23:56:57,033 - INFO - Successfully scraped and stored data for game: 2024-10-25-Minnesota-St Thomas
# Scraping games:  29%|██▊       | 142/498 [04:04<10:03,  1.70s/it]2024-12-10 23:56:57,983 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:56:58,765 - INFO - Successfully scraped and stored data for game: 2024-10-25-Rensselaer-Union
# Scraping games:  29%|██▊       | 143/498 [04:05<10:05,  1.71s/it]2024-12-10 23:56:59,596 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-10 23:57:00,381 - INFO - Successfully scraped and stored data for game: 2024-10-25-Massachusetts-Connecticut
# ...
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:05:26,895 - INFO - Successfully scraped and stored data for game: 2024-12-06-Harvard-Clarkson
# Scraping games:  91%|█████████ | 451/498 [12:34<01:17,  1.65s/it]2024-12-11 00:05:27,771 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:05:28,527 - INFO - Successfully scraped and stored data for game: 2024-12-06-Princeton-Union
# Scraping games:  91%|█████████ | 452/498 [12:35<01:15,  1.64s/it]2024-12-11 00:05:29,438 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:05:30,200 - INFO - Successfully scraped and stored data for game: 2024-12-06-Quinnipiac-Rensselaer
# Scraping games:  91%|█████████ | 453/498 [12:37<01:14,  1.65s/it]2024-12-11 00:05:31,121 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:05:31,900 - INFO - Successfully scraped and stored data for game: 2024-12-06-Northeastern-New Hampshire
# Scraping games:  91%|█████████ | 454/498 [12:39<01:13,  1.67s/it]2024-12-11 00:05:32,737 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:05:33,532 - INFO - Successfully scraped and stored data for game: 2024-12-06-Mass Lowell-Boston College
# Scraping games:  91%|█████████▏| 455/498 [12:40<01:11,  1.66s/it]2024-12-11 00:05:34,338 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:05:35,134 - INFO - Successfully scraped and stored data for game: 2024-12-06-Western Michigan-Denver
# Scraping games:  92%|█████████▏| 456/498 [12:42<01:08,  1.64s/it]2024-12-11 00:05:36,071 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:05:36,794 - INFO - Successfully scraped and stored data for game: 2024-12-06-Arizona State-Minnesota Duluth
# Scraping games:  92%|█████████▏| 457/498 [12:43<01:07,  1.65s/it]2024-12-11 00:05:37,721 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:05:38,505 - INFO - Successfully scraped and stored data for game: 2024-12-06-Miami-North Dakota
# Scraping games:  92%|█████████▏| 458/498 [12:45<01:06,  1.66s/it]2024-12-11 00:05:39,405 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:05:40,205 - INFO - Successfully scraped and stored data for game: 2024-12-06-St Cloud State-Omaha
# Scraping games:  92%|█████████▏| 459/498 [12:47<01:05,  1.67s/it]2024-12-11 00:05:41,029 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:05:41,805 - INFO - Successfully scraped and stored data for game: 2024-12-06-Minnesota-Michigan
# Scraping games:  92%|█████████▏| 460/498 [12:48<01:02,  1.66s/it]2024-12-11 00:05:42,684 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:05:43,505 - INFO - Successfully scraped and stored data for game: 2024-12-06-Ohio State-Penn State
# Scraping games:  93%|█████████▎| 461/498 [12:50<01:01,  1.67s/it]2024-12-11 00:05:44,420 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:05:45,105 - INFO - Successfully scraped and stored data for game: 2024-12-06-Wisconsin-Michigan State
# Scraping games:  93%|█████████▎| 462/498 [12:52<00:59,  1.65s/it]2024-12-11 00:05:46,036 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:05:46,771 - INFO - Successfully scraped and stored data for game: 2024-12-06-Merrimack-Alaska Anchorage
# Scraping games:  93%|█████████▎| 463/498 [12:53<00:57,  1.65s/it]2024-12-11 00:05:47,772 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:05:48,673 - INFO - Successfully scraped and stored data for game: 2024-12-06-Providence-Colorado College
# Scraping games:  93%|█████████▎| 464/498 [12:55<00:58,  1.73s/it]2024-12-11 00:05:49,506 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:05:50,344 - INFO - Successfully scraped and stored data for game: 2024-12-06-Vermont-Long Island
# Scraping games:  93%|█████████▎| 465/498 [12:57<00:56,  1.71s/it]2024-12-11 00:05:51,164 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:05:51,958 - INFO - Successfully scraped and stored data for game: 2024-12-06-Alaska-Augustana
# Scraping games:  94%|█████████▎| 466/498 [12:59<00:53,  1.68s/it]2024-12-11 00:05:52,904 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:05:53,670 - INFO - Successfully scraped and stored data for game: 2024-12-06-Lake Superior-Bemidji State
# Scraping games:  94%|█████████▍| 467/498 [13:00<00:52,  1.69s/it]2024-12-11 00:05:54,581 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:05:55,291 - INFO - Successfully scraped and stored data for game: 2024-12-06-Minnesota State-Bowling Green
# Scraping games:  94%|█████████▍| 468/498 [13:02<00:50,  1.67s/it]2024-12-11 00:05:56,204 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:05:56,871 - INFO - Successfully scraped and stored data for game: 2024-12-06-Northern Michigan-Ferris State
# Scraping games:  94%|█████████▍| 469/498 [13:04<00:47,  1.64s/it]2024-12-11 00:05:57,738 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:05:58,517 - INFO - Successfully scraped and stored data for game: 2024-12-06-Michigan Tech-St Thomas
# Scraping games:  94%|█████████▍| 470/498 [13:05<00:46,  1.64s/it]2024-12-11 00:05:59,351 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:00,171 - INFO - Successfully scraped and stored data for game: 2024-12-07-Canisius-Sacred Heart
# Scraping games:  95%|█████████▍| 471/498 [13:07<00:44,  1.65s/it]2024-12-11 00:06:01,004 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:01,754 - INFO - Successfully scraped and stored data for game: 2024-12-07-Mercyhurst-Bentley
# Scraping games:  95%|█████████▍| 472/498 [13:08<00:42,  1.63s/it]2024-12-11 00:06:02,634 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:03,352 - INFO - Successfully scraped and stored data for game: 2024-12-07-RIT-Robert Morris
# Scraping games:  95%|█████████▍| 473/498 [13:10<00:40,  1.62s/it]2024-12-11 00:06:04,237 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:04,921 - INFO - Successfully scraped and stored data for game: 2024-12-07-Air Force-Niagara
# Scraping games:  95%|█████████▌| 474/498 [13:12<00:38,  1.60s/it]2024-12-11 00:06:05,837 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:06,621 - INFO - Successfully scraped and stored data for game: 2024-12-07-Maine-Stonehill
# Scraping games:  95%|█████████▌| 475/498 [13:13<00:37,  1.63s/it]2024-12-11 00:06:07,473 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:08,212 - INFO - Successfully scraped and stored data for game: 2024-12-07-Providence-Colorado College
# Scraping games:  96%|█████████▌| 476/498 [13:15<00:35,  1.62s/it]2024-12-11 00:06:09,037 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:09,787 - INFO - Successfully scraped and stored data for game: 2024-12-07-Vermont-Long Island
# Scraping games:  96%|█████████▌| 477/498 [13:16<00:33,  1.61s/it]2024-12-11 00:06:10,718 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:11,430 - INFO - Successfully scraped and stored data for game: 2024-12-07-Merrimack-Alaska Anchorage
# Scraping games:  96%|█████████▌| 478/498 [13:18<00:32,  1.62s/it]2024-12-11 00:06:12,412 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:13,125 - INFO - Successfully scraped and stored data for game: 2024-12-07-Northeastern-Brown
# Scraping games:  96%|█████████▌| 479/498 [13:20<00:31,  1.64s/it]2024-12-11 00:06:14,049 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:14,726 - INFO - Successfully scraped and stored data for game: 2024-12-07-Alaska-Augustana
# Scraping games:  96%|█████████▋| 480/498 [13:21<00:29,  1.63s/it]2024-12-11 00:06:15,604 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:16,362 - INFO - Successfully scraped and stored data for game: 2024-12-07-Quinnipiac-Union
# Scraping games:  97%|█████████▋| 481/498 [13:23<00:27,  1.63s/it]2024-12-11 00:06:17,187 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:17,987 - INFO - Successfully scraped and stored data for game: 2024-12-07-Colgate-Cornell
# Scraping games:  97%|█████████▋| 482/498 [13:25<00:26,  1.63s/it]2024-12-11 00:06:18,925 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:19,637 - INFO - Successfully scraped and stored data for game: 2024-12-07-Dartmouth-Clarkson
# Scraping games:  97%|█████████▋| 483/498 [13:26<00:24,  1.64s/it]2024-12-11 00:06:20,517 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:21,179 - INFO - Successfully scraped and stored data for game: 2024-12-07-Harvard-St Lawrence
# Scraping games:  97%|█████████▋| 484/498 [13:28<00:22,  1.61s/it]2024-12-11 00:06:22,116 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:22,787 - INFO - Successfully scraped and stored data for game: 2024-12-07-Princeton-Rensselaer
# Scraping games:  97%|█████████▋| 485/498 [13:29<00:20,  1.61s/it]2024-12-11 00:06:23,687 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:24,537 - INFO - Successfully scraped and stored data for game: 2024-12-07-Arizona State-Minnesota Duluth
# Scraping games:  98%|█████████▊| 486/498 [13:31<00:19,  1.65s/it]2024-12-11 00:06:25,387 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:26,179 - INFO - Successfully scraped and stored data for game: 2024-12-07-St Cloud State-Omaha
# Scraping games:  98%|█████████▊| 487/498 [13:33<00:18,  1.65s/it]2024-12-11 00:06:27,024 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:27,774 - INFO - Successfully scraped and stored data for game: 2024-12-07-Western Michigan-Denver
# Scraping games:  98%|█████████▊| 488/498 [13:34<00:16,  1.63s/it]2024-12-11 00:06:28,654 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:29,320 - INFO - Successfully scraped and stored data for game: 2024-12-07-Miami-North Dakota
# Scraping games:  98%|█████████▊| 489/498 [13:36<00:14,  1.60s/it]2024-12-11 00:06:30,270 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:30,988 - INFO - Successfully scraped and stored data for game: 2024-12-07-Minnesota-Michigan
# Scraping games:  98%|█████████▊| 490/498 [13:38<00:12,  1.62s/it]2024-12-11 00:06:31,943 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:32,736 - INFO - Successfully scraped and stored data for game: 2024-12-07-Wisconsin-Michigan State
# Scraping games:  99%|█████████▊| 491/498 [13:39<00:11,  1.66s/it]2024-12-11 00:06:33,620 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:34,357 - INFO - Successfully scraped and stored data for game: 2024-12-07-Boston University-Massachusetts
# Scraping games:  99%|█████████▉| 492/498 [13:41<00:09,  1.65s/it]2024-12-11 00:06:35,191 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:35,948 - INFO - Successfully scraped and stored data for game: 2024-12-07-Lake Superior-Bemidji State
# Scraping games:  99%|█████████▉| 493/498 [13:43<00:08,  1.63s/it]2024-12-11 00:06:36,803 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:37,591 - INFO - Successfully scraped and stored data for game: 2024-12-07-Minnesota State-Bowling Green
# Scraping games:  99%|█████████▉| 494/498 [13:44<00:06,  1.64s/it]2024-12-11 00:06:38,503 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:39,176 - INFO - Successfully scraped and stored data for game: 2024-12-07-Northern Michigan-Ferris State
# Scraping games:  99%|█████████▉| 495/498 [13:46<00:04,  1.62s/it]2024-12-11 00:06:40,073 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:40,780 - INFO - Successfully scraped and stored data for game: 2024-12-07-Michigan Tech-St Thomas
# Scraping games: 100%|█████████▉| 496/498 [13:47<00:03,  1.62s/it]2024-12-11 00:06:41,653 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:42,454 - INFO - Successfully scraped and stored data for game: 2024-12-08-Maine-Stonehill
# Scraping games: 100%|█████████▉| 497/498 [13:49<00:01,  1.63s/it]2024-12-11 00:06:43,307 - INFO - Line chart DataFrame structure: Team        object
# Line        object
# Position    object
# Player      object
# dtype: object
# 2024-12-11 00:06:44,087 - INFO - Successfully scraped and stored data for game: 2024-12-09-Boston College-Mass Lowell
# Scraping games: 100%|██████████| 498/498 [13:51<00:00,  1.67s/it]
# 2024-12-11 00:06:44,087 - INFO - Scraping completed with 0 errors.

# %% [markdown]
# #### Add the Roster data from the CSV to the Database

# %%
# open the database connection
# conn = sqlite3.connect(db_path)

# %%
################## SET THE ROSTER DATAFRAME TO THE CORRECT YEAR ####################
## Load the roster data from CSV
roster_filename = 'roster_2024_current_v3.csv'
# Load to DataFrame
roster_df = pd.read_csv(f'../data/{roster_filename}')

# Set the SeasonYear in the database_roster
season_year_setting = 2024

## MATCH THE DATAFRAME NAMES
df_master_roster = roster_df.copy()

## Season Year Value
season_year = season_year_setting

# Clean up the name formats for joining
# Master roster: Convert "Last Name, First Name" to "First Name Last Name"
# df_master_roster['Clean_Name'] = df_master_roster['Player'].apply(lambda x: ' '.join(reversed(x.split(', '))))

# Rename Player to Clean_Name
df_master_roster.rename(columns={'Player': 'Clean_Name'}, inplace=True)
# Rename School to Team
df_master_roster.rename(columns={'School': 'Team'}, inplace=True)

# Clean up the Team column, remove '-' and replace with ' '
# df_master_roster['School'] = df_master_roster['Team'].apply(lambda x: x.replace('-', ' '))

## If there are an period in the column names, remove them
df_master_roster.columns = df_master_roster.columns.str.replace('.', '')

### Finally add the roster to the database as it's own table

df_master_roster['SeasonYear'] = season_year

# Save the roster data as a new table in the database
roster_table_name = 'master_roster'
df_master_roster.to_sql(roster_table_name, conn, if_exists='replace', index=False)
############################################################

# Verify by listing all the tables in the database again
tables_query = "SELECT name FROM sqlite_master WHERE type='table';"
tables = conn.execute(tables_query).fetchall()
table_names_updated = [table[0] for table in tables]
table_names_updated
# Out:
# ['game_details',
#  'scoring_summary',
#  'penalty_summary',
#  'goalie_stats',
#  'player_stats',
#  'line_chart',
#  'linescore',
#  'advanced_metrics',
#  'master_roster']

# %% [markdown]
# #### Clean up The Column Names and extra header rows in the Player Stats table

# %%
player_stats_df = pd.read_sql_query("SELECT * FROM player_stats", conn)

# Define a dictionary for column renaming
column_renames = {
    'Pt.': 'Pts',
    '+/-': 'plus_minus'
}

# Rename columns based on the dictionary
player_stats_df.rename(columns=column_renames, inplace=True)


# Drop rows where Team name is in the Player column
player_stats_df = player_stats_df[player_stats_df['Team'] != player_stats_df['Player']]

## Change the Column names to be easy to work with
############ 'Pt.' should be 'Pts' and '+/-' should be 'plus_minus'
#################################
player_stats_df = pd.read_sql_query("SELECT * FROM player_stats", conn)

if 'Pt.' in player_stats_df.columns:
    player_stats_df.rename(columns={'Pt.': 'Pts'}, inplace=True)
else:
    print("Column 'Pt.' not found.")

if '+/-' in player_stats_df.columns:
    player_stats_df.rename(columns={'+/-': 'plus_minus'}, inplace=True)
else:
    print("Column '+/-' not found.")

print(len(player_stats_df))

# Drop rows if Team name is in the player column
# If ['Team'] is the same as ['Player'] then drop that row
player_stats_df = player_stats_df[player_stats_df['Team'] != player_stats_df['Player']]

# add the dataframe back to the database
player_stats_df.to_sql('player_stats', conn, if_exists='replace', index=False)
# Out:
# 21042
# 20160

# %% [markdown]
# #### CREATE A NEW TABLE WITH AGGRIGATED PLAYER STATS YEAR TO DATE

# %%
## Load the player_stats table into df_player_stats

# Query to load the player_stats table
player_stats_query = "SELECT * FROM player_stats"
df_player_stats = pd.read_sql(player_stats_query, conn)

# Address problem where header rows of each game were added to the table
# If Team and Player columns match remove the row
df_player_stats = df_player_stats[df_player_stats['Team'] != 'Team']

# Replace the non-breaking space with a regular space
df_player_stats['Player'] = df_player_stats['Player'].apply(lambda x: x.replace('\xa0', ' '))

# Convert relevant columns to integers for correct aggregation
cols_to_convert = ['G', 'A', 'Pts', 'plus_minus', 'Sh', 'PIM']
for col in cols_to_convert:
    df_player_stats[col] = pd.to_numeric(df_player_stats[col], errors='coerce')

# Aggregate the data for year-to-date stats
# Add a column for counting the number of games each player has played
agg_player_stats_corrected_with_games = df_player_stats.groupby(['Player', 'Team']).agg({
    'G': 'sum',
    'A': 'sum',
    'Pts': 'sum',
    'plus_minus': 'sum',
    'Sh': 'sum',
    'PIM': 'sum',
    'Game_ID': 'count'  # Counting the number of unique Game_IDs for each player
}).reset_index()

# Rename the Game_ID column to Games_Played
agg_player_stats_corrected_with_games.rename(columns={'Game_ID': 'Games_Played'}, inplace=True)

# Save the updated aggregated data back to the database, replacing the existing table
agg_player_stats_corrected_with_games.to_sql('player_stats_ytd', conn, if_exists='replace', index=False)
# Out:
# 1704

# %% [markdown]
# ## Clean up / Rename COlumns in Advanced Stats

# %%
## NEW Handling of Advanced Stats
# Create dataframe from SQL query
df = pd.read_sql_query("SELECT * FROM advanced_metrics", conn)

# Rename columns
new_names = ['Team', 'Player', 'TOTAL_Block', 'TOTAL_Miss', 'TOTAL_Saved', 'TOTAL_Goals', 'TOTAL_Total_Shots',
                'EVEN_Block', 'EVEN_Miss', 'EVEN_Saved', 'EVEN_Goals', 'EVEN_Total_Shots',
                'PP_Block', 'PP_Miss', 'PP_Saved', 'PP_Goals', 'PP_Total_Shots',
                'CLOSE_Block', 'CLOSE_Miss', 'CLOSE_Saved', 'CLOSE_Goals', 'CLOSE_Total_Shots',

                'D_Blocks', 'Faceoffs', 'Game_ID']

df.columns = new_names

# Remove all rows where Player = TOTAL
df = df[df['Player'] != 'TOTAL']

# # Apply the matched_dict to the Team column
# df['Team'] = df['Team'].apply(lambda x: matched_dict[x])

## Fill all NaN values with 0
df = df.fillna(0)

# Display the dataframe
df.head()

# Save back to the database
df.to_sql('advanced_metrics', conn, if_exists='replace', index=False)
# Out:
# 18965

# %%
## TEMP CODE
# Database Name
# DB_FILE_NAME = 'CHN_2024_YTD_Stats.db'
DB_FILE_NAME = '12_10_Test_p2.db'
# Database Path
db_path = f'../data/db/{DB_FILE_NAME}'
# Open the database connection
conn = sqlite3.connect(db_path)

# print table names
tables_query = "SELECT name FROM sqlite_master WHERE type='table';"
tables = conn.execute(tables_query).fetchall()
table_names = [table[0] for table in tables]
table_names
# Out:
# []

# %% [markdown]
# ### Add Home_Team and Away_Team Columns to tables where needed

# %%
# Step 1: Read the game_details table into a DataFrame
df_game_details = pd.read_sql("SELECT * FROM game_details", conn)

# Step 2: Create new columns for Home and Away Teams by parsing Game_ID
df_game_details['Away_Team'] = df_game_details['Game_ID'].apply(lambda x: x.split('-')[4])
df_game_details['Home_Team'] = df_game_details['Game_ID'].apply(lambda x: x.split('-')[3])

# Step 3: Write this updated DataFrame back to the game_details table
df_game_details.to_sql('game_details', conn, if_exists='replace', index=False)
# Out:
# 497

# %%
## Select scoring_summary table into a DataFrame and add the Home_Team and Away_Team columns
df_scoring_summary = pd.read_sql("SELECT * FROM scoring_summary", conn)

# Add Home_Team and Away_Team columns
df_scoring_summary['Away_Team'] = df_scoring_summary['Game_ID'].apply(lambda x: x.split('-')[4])
df_scoring_summary['Home_Team'] = df_scoring_summary['Game_ID'].apply(lambda x: x.split('-')[3])

# Write the updated DataFrame back to the scoring_summary table
df_scoring_summary.to_sql('scoring_summary', conn, if_exists='replace', index=False)
# Out:
# 2728

# %%
## Close the database connection
conn.close()

# shutdown logging
logging.shutdown()

# %%
# df.head(20)
